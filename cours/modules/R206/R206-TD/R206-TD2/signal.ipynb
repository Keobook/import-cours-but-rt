# %%
import matplotlib.pyplot as plt

s = [5, 8, 9, 7, 3, 0, 0, 4, 8, 9, 7, 3, 0, 0, 3, 7, 9,
     8, 4, 0, 0, 3, 7, 9, 8, 5, 1, 0, 2, 6, 9, 9, 5, 1,0]

plt.scatter(range(0, len(s)), s)

# %%
s_sec = [s[i-1] for i in range(0, len(s))]
print(s_sec)

plt.scatter(range(0, len(s)), s_sec)
# Out:
# [0, 5, 8, 9, 7, 3, 0, 0, 4, 8, 9, 7, 3, 0, 0, 3, 7, 9, 8, 4, 0, 0, 3, 7, 9, 8, 5, 1, 0, 2, 6, 9, 9, 5, 1]

# %%
n = 2

s_prime = [s[i-n] for i in range(0, len(s))]

# %% [markdown]
# Avec $S^{"}_{num}[k] = s_{num}[k-N]$
#
# Donc $S_{moy}[k] = \frac{s[k-1] + s[k] + s[k+1]}{3}$

# %%
s_moy = [(s_sec[i-2] + s_sec[i-1] + s_sec[i])/3 for i in range(2, len(s_sec))]
print(s_moy[:3])
plt.scatter(range(0, len(s_moy)), s_moy)
# Out:
# [4.333333333333333, 7.333333333333333, 8.0]
